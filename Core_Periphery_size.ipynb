# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import collections
import geopandas as gpd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import math
from matplotlib.ticker import MultipleLocator

# %%
df = pd.read_csv('data_USA.csv')

# %%
G = nx.from_pandas_edgelist(df, source = 'Source', target = 'Target', edge_attr = 'Weight', create_using = nx.DiGraph)

# %%
periphery_df =df[['Source', 'Target']]
periphery_df['Source_d'] = ''
periphery_df['Target_d'] = ''
periphery_df['Kplus'] = ''
degree_list = G.degree()

for i in range(0, len(periphery_df)):
    periphery_df.loc[i, 'Source_d'] = degree_list[periphery_df.Source[i]]
    periphery_df.loc[i, 'Target_d'] = degree_list[periphery_df.Target[i]]
    
    if periphery_df.Target_d[i] > periphery_df.Source_d[i]:
        periphery_df.loc[i, 'Kplus'] = 1
    else:
        periphery_df.loc[i, 'Kplus'] = 0
        
plot_periphery = periphery_df.groupby(['Source'],as_index=False).agg({'Source':'first', 'Source_d':'first','Kplus':'sum'}).reset_index(drop=True)
plot_periphery = plot_periphery.sort_values(by=['Source_d'], ascending=False).reset_index(drop=True)

fig, ax1 = plt.subplots(figsize=(15,5))
ax1.grid('on', alpha=.2)
ax1.set_axisbelow(True)
periphery_data = plot_periphery['Kplus'].tolist()
ax1.plot(periphery_data, 'r-')
ax1.set_title('Core Periphery for USA')
ax1.set_xlabel('Node Number (Ranked by Descending Order)')
ax1.set_ylabel('Number of Connections to Higher Degree Nodes')
plt.show()
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_18596\4107043481.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   periphery_df['Source_d'] = ''
# C:\Users\david\AppData\Local\Temp\ipykernel_18596\4107043481.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   periphery_df['Target_d'] = ''
# C:\Users\david\AppData\Local\Temp\ipykernel_18596\4107043481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
de = pd.read_csv('data_UK.csv')

# %%
B = nx.from_pandas_edgelist(de, source = 'Source', target = 'Target', edge_attr = 'weight', create_using = nx.DiGraph)

# %%
periphery_df_uk = de[['Source', 'Target']]
periphery_df_uk['Source_d'] = ''
periphery_df_uk['Target_d'] = ''
periphery_df_uk['Kplus'] = ''
uk_degree_list = B.degree()

for i in range(0, len(periphery_df_uk)):
    periphery_df_uk.loc[i, 'Source_d'] = uk_degree_list[periphery_df_uk.Source[i]]
    periphery_df_uk.loc[i, 'Target_d'] = uk_degree_list[periphery_df_uk.Target[i]]
    
    if periphery_df_uk.Target_d[i] > periphery_df_uk.Source_d[i]:
        periphery_df_uk.loc[i, 'Kplus'] = 1
    else:
        periphery_df_uk.loc[i, 'Kplus'] = 0
        
plot_periphery = periphery_df_uk.groupby(['Source'],as_index=False).agg({'Source':'first', 'Source_d':'first','Kplus':'sum'}).reset_index(drop=True)
plot_periphery = plot_periphery.sort_values(by=['Source_d'], ascending=False).reset_index(drop=True)

fig, ax1 = plt.subplots(figsize=(15,5))
ax1.grid('on', alpha=.2)
ax1.set_axisbelow(True)
periphery_data = plot_periphery['Kplus'].tolist()
ax1.plot(periphery_data, 'r-')
ax1.set_title('Core Periphery for UK')
ax1.set_xlabel('Node Number (Ranked by Descending Order)')
ax1.set_ylabel('Number of Connections to Higher Degree Nodes')
plt.show()
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_18596\1648458956.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   periphery_df_uk['Source_d'] = ''
# C:\Users\david\AppData\Local\Temp\ipykernel_18596\1648458956.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   periphery_df_uk['Target_d'] = ''
# C:\Users\david\AppData\Local\Temp\ipykernel_18596\1648458956.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dc = pd.read_csv('data_AUS.csv')

# %%
A = nx.from_pandas_edgelist(dc, source = 'Source', target = 'Target', edge_attr = 'weight', create_using = nx.DiGraph)

# %%
periphery_df_au = dc[['Source', 'Target']]
periphery_df_au['Source_d'] = ''
periphery_df_au['Target_d'] = ''
periphery_df_au['Kplus'] = ''
a_degree_list = A.degree()

for i in range(0, len(periphery_df_au)):
    periphery_df_au.loc[i, 'Source_d'] = a_degree_list[periphery_df_au.Source[i]]
    periphery_df_au.loc[i, 'Target_d'] = a_degree_list[periphery_df_au.Target[i]]
    
    if periphery_df_au.Target_d[i] > periphery_df_au.Source_d[i]:
        periphery_df_au.loc[i, 'Kplus'] = 1
    else:
        periphery_df_au.loc[i, 'Kplus'] = 0
        
plot_periphery = periphery_df_au.groupby(['Source'],as_index=False).agg({'Source':'first', 'Source_d':'first','Kplus':'sum'}).reset_index(drop=True)
plot_periphery = plot_periphery.sort_values(by=['Source_d'], ascending=False).reset_index(drop=True)

fig, ax1 = plt.subplots(figsize=(15,5))
ax1.grid('on', alpha=.2)
ax1.set_axisbelow(True)
periphery_data = plot_periphery['Kplus'].tolist()
ax1.plot(periphery_data, 'r-')
ax1.set_title('Core Periphery for Australia')
ax1.set_xlabel('Node Number (Ranked by Descending Order)')
ax1.set_ylabel('Number of Connections to Higher Degree Nodes')
plt.show()
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_18596\3763446349.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   periphery_df_au['Source_d'] = ''
# C:\Users\david\AppData\Local\Temp\ipykernel_18596\3763446349.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   periphery_df_au['Target_d'] = ''
# C:\Users\david\AppData\Local\Temp\ipykernel_18596\3763446349.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
db = pd.read_csv('data_China.csv')

# %%
C = nx.from_pandas_edgelist(db, source = 'Source', target = 'Target', edge_attr = 'weight', create_using = nx.DiGraph)

# %%
periphery_df_c = db[['Source', 'Target']]
periphery_df_c['Source_d'] = ''
periphery_df_c['Target_d'] = ''
periphery_df_c['Kplus'] = ''
a_degree_list = C.degree()

for i in range(0, len(periphery_df_c)):
    periphery_df_c.loc[i, 'Source_d'] = a_degree_list[periphery_df_c.Source[i]]
    periphery_df_c.loc[i, 'Target_d'] = a_degree_list[periphery_df_c.Target[i]]
    
    if periphery_df_c.Target_d[i] > periphery_df_c.Source_d[i]:
        periphery_df_c.loc[i, 'Kplus'] = 1
    else:
        periphery_df_c.loc[i, 'Kplus'] = 0
        
plot_periphery = periphery_df_c.groupby(['Source'],as_index=False).agg({'Source':'first', 'Source_d':'first','Kplus':'sum'}).reset_index(drop=True)
plot_periphery = plot_periphery.sort_values(by=['Source_d'], ascending=False).reset_index(drop=True)

fig, ax1 = plt.subplots(figsize=(15,5))
ax1.grid('on', alpha=.2)
ax1.set_axisbelow(True)
periphery_data = plot_periphery['Kplus'].tolist()
ax1.plot(periphery_data, 'r-')
ax1.set_title('Core Periphery for China')
ax1.set_xlabel('Node Number (Ranked by Descending Order)')
ax1.set_ylabel('Number of Connections to Higher Degree Nodes')
plt.show()
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_18596\1727227901.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   periphery_df_c['Source_d'] = ''
# C:\Users\david\AppData\Local\Temp\ipykernel_18596\1727227901.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   periphery_df_c['Target_d'] = ''
# C:\Users\david\AppData\Local\Temp\ipykernel_18596\1727227901.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
